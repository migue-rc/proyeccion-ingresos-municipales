# %% [markdown]
# # Pronóstico 6→6 especializado por ingreso, clúster 1
#
# [← Metodología común](metodologia-pronostico-6x6.ipynb) ·
# [← Resultados del modelo conjunto](cluster1.ipynb)
#
# Este notebook es un experimento independiente. El modelo seleccionado en
# `cluster1.ipynb` es el benchmark conjunto, donde un solo estimador genera los 30
# objetivos. Aquí se ajusta una suite por cada uno de los cinco ingresos y se construye
# una solución híbrida seleccionada exclusivamente con validación histórica.

# %%
# Configuración editable
from utils.forecasting_cache import ForecastCacheConfig

CLUSTER_COLUMN = "cluster1"
TRAINING_START = "2016-01-01"
PREFERRED_MUNICIPALITY = "Providencia"
TOTAL_WAPE_GUARDRAIL = 0.01

MODEL_CACHE = ForecastCacheConfig(
    directory="model_cache",
    enabled=True,
    refresh=False,
)

# Opcional: puede asignarse aquí un resultado ya calculado por
# run_cluster_forecasting_workflow con la misma configuración y los mismos cortes.
JOINT_WORKFLOW_RESULT = None

# %% [markdown]
# ## Punto de partida del experimento especializado
#
# El experimento reutiliza las comunas y el inicio de entrenamiento de `cluster1`, junto
# con el contrato, los cortes y la cobertura definidos en la
# [metodología común](metodologia-pronostico-6x6.ipynb). Su única diferencia comienza en
# la arquitectura de salida y en la regla que combina especialistas.

# %%
import warnings

import pandas as pd
from IPython.display import HTML, display

from utils.data import data_loader
from utils.forecasting import FORECAST_INCOME_GROUPS
from utils.forecasting_cache import summarize_cache_report
from utils.forecasting_workflow import resolve_cluster_municipalities
from utils.notebook_display import collapsible_stdout, display_collapsible
from utils.plots import (
    plot_cluster_municipality_improvement,
    plot_hybrid_combination_frontier,
    plot_joint_hybrid_improvement_matrix,
    plot_specialized_family_comparison,
)
from utils.separated_forecasting import (
    AVERAGE_INCOME_GROUP_LABEL,
    HYBRID_ARCHITECTURE,
    JOINT_ARCHITECTURE,
    SATISFACTORY_IMPROVEMENT_COLUMNS,
    TEST_PERIOD_LABEL,
    build_joint_hybrid_improvement_summary,
    build_separated_municipality_forecast_view,
    run_separated_income_forecasting_workflow,
)

warnings.filterwarnings(
    "ignore",
    message=(
        r"`sklearn\.utils\.parallel\.delayed` should be used with "
        r"`sklearn\.utils\.parallel\.Parallel`.*"
    ),
    category=UserWarning,
    module=r"sklearn\.utils\.parallel",
)

clusters = pd.read_csv("clusters.csv")
municipalities = resolve_cluster_municipalities(clusters, CLUSTER_COLUMN)
with collapsible_stdout("Ver registro de carga de datos"):
    presupuesto_cluster = data_loader(municipalities=municipalities)

display_collapsible(
    "Ver configuración efectiva",
    pd.DataFrame(
        {
            "cluster": [CLUSTER_COLUMN],
            "comunas": [len(municipalities)],
            "inicio de entrenamiento": [pd.Timestamp(TRAINING_START)],
            "comuna para detalle": [PREFERRED_MUNICIPALITY],
            "guardrail WAPE total": [TOTAL_WAPE_GUARDRAIL],
            "caché habilitado": [MODEL_CACHE.enabled],
            "refrescar caché": [MODEL_CACHE.refresh],
            "directorio caché": [str(MODEL_CACHE.directory)],
        }
    )
)
municipality_label = "comuna" if len(municipalities) == 1 else "comunas"
municipality_items = "".join(
    f"<li>{municipality}</li>" for municipality in municipalities
)
display_collapsible(
    f"Ver {len(municipalities)} {municipality_label} del clúster",
    HTML(
        f'<ul class="cluster-members__list">{municipality_items}</ul>'
    )
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver configuración efectiva</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>comunas</th>
#       <th>inicio de entrenamiento</th>
#       <th>comuna para detalle</th>
#       <th>guardrail WAPE total</th>
#       <th>caché habilitado</th>
#       <th>refrescar caché</th>
#       <th>directorio caché</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cluster1</td>
#       <td>5</td>
#       <td>2016-01-01</td>
#       <td>Providencia</td>
#       <td>0.01</td>
#       <td>True</td>
#       <td>False</td>
#       <td>model_cache</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver 5 comunas del clúster</summary><div class="collapsible-output__content"><ul class="cluster-members__list"><li>Alhué</li><li>Huechuraba</li><li>Lo Barnechea</li><li>Providencia</li><li>Vitacura</li></ul></div></details>

# %% [markdown]
# ## Arquitectura conjunta frente a arquitecturas especializadas
#
# Todos los modelos reciben las mismas entradas del contrato común. La diferencia está
# únicamente en la salida.
#
# | Arquitectura | Modelos entrenados | Salida directa | Total disponible |
# |---|---:|---:|---|
# | Conjunta | 1 | 30 objetivos, 6 meses × 5 ingresos | suma de los cinco ingresos |
# | Separada | 5 | 6 objetivos por modelo, uno por ingreso | suma exacta de las cinco salidas |
# | Híbrida | hasta 5 especializados más el conjunto | elige una fuente por ingreso | suma exacta de las fuentes elegidas |
#
# > **Costo esperado:** el tuning especializado requiere aproximadamente cinco veces
# > más ajustes que el notebook conjunto. Si se entrega `JOINT_WORKFLOW_RESULT`, la
# > reutilización en memoria del benchmark tiene prioridad sobre el caché en disco.

# %% [markdown]
# ## Regla de selección congelada
#
# Para cada ingreso se ajustan Ridge, ExtraTrees y CatBoost con 2018–2022. Luego esas
# tres familias y Persistencia compiten en tres cortes de validación cuyos objetivos
# abarcan enero de 2024 a junio de 2025.
#
# Con los cinco ganadores especializados se evalúan las 32 combinaciones posibles entre
# fuente conjunta y especializada. Para cada combinación se calcula la mejora relativa
# de WAPE frente al modelo conjunto en `Transferencias corrientes`, `Transferencias de
# capital` y `Otros ingresos`, y se promedian esas tres mejoras con igual peso.
#
# Una combinación híbrida es elegible solo si ese promedio es estrictamente mayor que
# 5 % y su WAPE macro de `Total disponible` no empeora en más de 0,01 —un punto
# porcentual— respecto del conjunto. Entre las alternativas elegibles se elige la de
# mayor mejora prioritaria; los desempates favorecen menor WAPE total, menor WAPE
# promedio de los cinco ingresos, menos modelos especializados y un orden determinista.
# Si ninguna cumple ambos criterios, se selecciona `00000`, el modelo completamente
# conjunto. El mapa resultante se congela antes de calcular cualquier métrica de 2026.
#
# Las definiciones de WAPE macro, WAPE micro, MAE y sesgo se mantienen exactamente como
# en la [metodología común](metodologia-pronostico-6x6.ipynb).

# %%
with collapsible_stdout("Ver registro de entrenamiento especializado"):
    workflow = run_separated_income_forecasting_workflow(
        presupuesto_cluster,
        municipalities,
        cluster_label=CLUSTER_COLUMN,
        training_start=TRAINING_START,
        joint_result=JOINT_WORKFLOW_RESULT,
        total_guardrail=TOTAL_WAPE_GUARDRAIL,
        progress=True,
        cache_config=MODEL_CACHE,
    )

display_collapsible("Ver configuración del workflow", workflow.configuration)
display_collapsible("Ver ventanas de entrenamiento", workflow.training_windows)
display_collapsible(
    "Ver resumen del caché",
    summarize_cache_report(workflow.cache_report),
)

cache_by_stage = (
    workflow.cache_report.groupby(
        ["stage", "artifact_type", "status"], sort=False, dropna=False
    )
    .agg(artefactos=("key", "size"), gb=("size_bytes", lambda x: x.sum() / 1024**3))
    .reset_index()
)
display_collapsible("Ver artefactos de caché por etapa", cache_by_stage)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver configuración del workflow</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>cluster</th>
#       <th>comunas</th>
#       <th>inicio_entrenamiento_solicitado</th>
#       <th>primer_corte_tuning</th>
#       <th>ultimo_corte_tuning</th>
#       <th>primer_corte_validacion</th>
#       <th>ultimo_corte_validacion</th>
#       <th>fin_entrenamiento_final</th>
#       <th>entrada_final</th>
#       <th>test_congelado</th>
#       <th>ventanas_entrenamiento_final</th>
#       <th>variables_mensuales_por_modelo</th>
#       <th>objetivos_por_modelo_especializado</th>
#       <th>suites_especializadas</th>
#       <th>combinaciones_hibridas</th>
#       <th>guardrail_total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>cluster1</td>
#       <td>5</td>
#       <td>2016-01-01</td>
#       <td>2018-06-01</td>
#       <td>2022-12-01</td>
#       <td>2023-06-01</td>
#       <td>2024-06-01</td>
#       <td>2025-06-01</td>
#       <td>julio-diciembre 2025</td>
#       <td>enero-junio 2026</td>
#       <td>515</td>
#       <td>30</td>
#       <td>6</td>
#       <td>5</td>
#       <td>32</td>
#       <td>0.01</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver ventanas de entrenamiento</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre Municipio</th>
#       <th>primera_entrada</th>
#       <th>ultimo_objetivo</th>
#       <th>ventanas</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alhué</td>
#       <td>2016-01-01</td>
#       <td>2025-06-01</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Huechuraba</td>
#       <td>2016-01-01</td>
#       <td>2025-06-01</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Lo Barnechea</td>
#       <td>2016-01-01</td>
#       <td>2025-06-01</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Providencia</td>
#       <td>2016-01-01</td>
#       <td>2025-06-01</td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Vitacura</td>
#       <td>2016-01-01</td>
#       <td>2025-06-01</td>
#       <td>103</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver resumen del caché</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>hits</th>
#       <th>misses</th>
#       <th>modelos_cargados</th>
#       <th>evaluaciones_cargadas</th>
#       <th>reutilizaciones_memoria</th>
#       <th>artefactos_escritos</th>
#       <th>artefactos_corruptos_aislados</th>
#       <th>gb_cargados</th>
#       <th>gb_escritos</th>
#       <th>gb_artefactos_utilizados</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>687</td>
#       <td>0</td>
#       <td>8</td>
#       <td>679</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.103098</td>
#       <td>0.0</td>
#       <td>0.103098</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver artefactos de caché por etapa</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>stage</th>
#       <th>artifact_type</th>
#       <th>status</th>
#       <th>artefactos</th>
#       <th>gb</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>joint_tuning</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000418</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>joint_validation</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000021</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>specialized_tuning:Transferencias corrientes</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000168</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>specialized_validation:Transferencias corrientes</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>specialized_tuning:Transferencias de capital</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000162</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>specialized_validation:Transferencias de capital</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>specialized_tuning:Otros ingresos</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000169</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>specialized_validation:Otros ingresos</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>specialized_tuning:IPP</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000169</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>specialized_validation:IPP</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>specialized_tuning:FCM</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>110</td>
#       <td>0.000168</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>specialized_validation:FCM</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.000006</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>joint_final_model</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>3</td>
#       <td>0.051384</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>specialized_final_model:Transferencias corrientes</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.004524</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>specialized_final_model:Transferencias de capital</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.014027</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>specialized_final_model:Otros ingresos</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.006607</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>specialized_final_model:IPP</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.014686</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>specialized_final_model:FCM</td>
#       <td>model</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.010558</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>separated_test</td>
#       <td>evaluation</td>
#       <td>hit</td>
#       <td>1</td>
#       <td>0.000005</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>

# %% [markdown]
# ## Del modelo de `cluster1.ipynb` a los especialistas
#
# El benchmark conserva el ganador conjunto seleccionado por WAPE macro de `Total
# disponible` en `cluster1.ipynb`. La tabla identifica los cinco ganadores especializados
# y el mapa de calor muestra cuánto se separa cada familia del mejor modelo de su
# ingreso. Ninguna de estas decisiones usa 2026.

# %%
joint_ranking = workflow.joint_validation_ranking.copy()
joint_ranking["WAPE macro (%)"] = (100 * joint_ranking["wape_macro"]).round(2)
joint_ranking["WAPE micro (%)"] = (100 * joint_ranking["wape_micro"]).round(2)
display_collapsible(
    "Ver ranking del modelo conjunto",
    joint_ranking[
        [
            "ranking",
            "seleccion_validacion",
            "modelo",
            "WAPE macro (%)",
            "WAPE micro (%)",
            "mae_mm_clp",
            "sesgo_micro_mm_clp",
        ]
    ]
)

comparison_summary = build_joint_hybrid_improvement_summary(workflow)
specialized_winners = workflow.specialized_winners.copy()
specialized_winners["WAPE macro validación (%)"] = (
    100 * specialized_winners["wape_macro_validacion"]
).round(2)
specialized_winners["WAPE micro validación (%)"] = (
    100 * specialized_winners["wape_micro_validacion"]
).round(2)
display_collapsible(
    "Ver modelos especializados seleccionados",
    specialized_winners[
        [
            "grupo_ingreso",
            "modelo_especializado",
            "candidate_id",
            "parametros",
            "WAPE macro validación (%)",
        ]
    ]
)

family_figure = plot_specialized_family_comparison(
    workflow.joint_validation_summary,
    workflow.specialized_validation_summary,
    workflow.specialized_winners,
    joint_model_name=workflow.joint_selected_model_name,
)
display(
    HTML(
        family_figure.to_html(
            full_html=False,
            include_plotlyjs="cdn",
            config={"responsive": True, "displaylogo": False},
        )
    )
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver ranking del modelo conjunto</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ranking</th>
#       <th>seleccion_validacion</th>
#       <th>modelo</th>
#       <th>WAPE macro (%)</th>
#       <th>WAPE micro (%)</th>
#       <th>mae_mm_clp</th>
#       <th>sesgo_micro_mm_clp</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>True</td>
#       <td>ExtraTrees global</td>
#       <td>22.48</td>
#       <td>20.71</td>
#       <td>1429.203237</td>
#       <td>-1131.222871</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>False</td>
#       <td>Ridge global</td>
#       <td>30.13</td>
#       <td>25.26</td>
#       <td>1742.770736</td>
#       <td>340.759796</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>False</td>
#       <td>CatBoost global</td>
#       <td>30.35</td>
#       <td>26.91</td>
#       <td>1856.700167</td>
#       <td>-1539.450122</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>False</td>
#       <td>Persistencia</td>
#       <td>56.03</td>
#       <td>54.77</td>
#       <td>3778.843687</td>
#       <td>-1154.029019</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver modelos especializados seleccionados</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grupo_ingreso</th>
#       <th>modelo_especializado</th>
#       <th>candidate_id</th>
#       <th>parametros</th>
#       <th>WAPE macro validación (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Transferencias corrientes</td>
#       <td>ExtraTrees global</td>
#       <td>extra_trees_depth_12_leaf_3</td>
#       <td>{'n_estimators': 400, 'max_depth': 12, 'min_sa...</td>
#       <td>74.54</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Transferencias de capital</td>
#       <td>ExtraTrees global</td>
#       <td>extra_trees_depth_none_leaf_1</td>
#       <td>{'n_estimators': 400, 'max_depth': None, 'min_...</td>
#       <td>332.74</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Otros ingresos</td>
#       <td>ExtraTrees global</td>
#       <td>extra_trees_depth_none_leaf_3</td>
#       <td>{'n_estimators': 400, 'max_depth': None, 'min_...</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>IPP</td>
#       <td>ExtraTrees global</td>
#       <td>extra_trees_depth_none_leaf_1</td>
#       <td>{'n_estimators': 400, 'max_depth': None, 'min_...</td>
#       <td>19.50</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>FCM</td>
#       <td>ExtraTrees global</td>
#       <td>extra_trees_depth_12_leaf_1</td>
#       <td>{'n_estimators': 400, 'max_depth': 12, 'min_sa...</td>
#       <td>20.60</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <div style="height:560px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="c9ec5301-ac8e-4c4f-98fd-81780c5a0251" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("c9ec5301-ac8e-4c4f-98fd-81780c5a0251")) {                    Plotly.newPlot(                        "c9ec5301-ac8e-4c4f-98fd-81780c5a0251",                        [{"colorbar":{"title":{"text":"Brecha vs.\u003cbr\u003emejor (%)"}},"colorscale":[[0.0,"#D9F0E7"],[0.35,"#F7F7F7"],[1.0,"#D55E00"]],"customdata":[[["Transferencias corrientes","Conjunto ExtraTrees global",75.84268275050589,1.7422468292176863,""],["Transferencias corrientes","Persistencia",75.90773811543026,1.82951799046438,""],["Transferencias corrientes","Ridge especializado",98.37306146040955,31.966538332717786,""],["Transferencias corrientes","ExtraTrees especializado",74.54394326263873,0.0,"Ganador especializado"],["Transferencias corrientes","CatBoost especializado",79.63669467636872,6.8318782061029815,""]],[["Transferencias de capital","Conjunto ExtraTrees global",433.72918708734005,30.34948849985146,""],["Transferencias de capital","Persistencia",355.9773554286822,6.982577099001386,""],["Transferencias de capital","Ridge especializado",542.8793906565186,63.15261457130963,""],["Transferencias de capital","ExtraTrees especializado",332.74329809727965,0.0,"Ganador especializado"],["Transferencias de capital","CatBoost especializado",386.10878127289374,16.03803396815895,""]],[["Otros ingresos","Conjunto ExtraTrees global",60.43410380003191,3.3327924416352905,""],["Otros ingresos","Persistencia",114.9312613287871,96.51434248515538,""],["Otros ingresos","Ridge especializado",78.97710013104538,35.03839359456586,""],["Otros ingresos","ExtraTrees especializado",58.48492271624855,0.0,"Ganador especializado"],["Otros ingresos","CatBoost especializado",67.66748378692691,15.700732161739218,""]],[["IPP","Conjunto ExtraTrees global",22.808393686048554,16.94921636179312,""],["IPP","Persistencia",62.85938336286001,222.30922205489176,""],["IPP","Ridge especializado",33.98790661802107,74.27176588883195,""],["IPP","ExtraTrees especializado",19.502818740989845,0.0,"Ganador especializado"],["IPP","CatBoost especializado",23.62034434874208,21.112464113191322,""]],[["FCM","Conjunto ExtraTrees global",27.138425348591323,31.749923979269546,""],["FCM","Persistencia",72.82445900487664,253.5436125892234,""],["FCM","Ridge especializado",76.49091942215405,271.3433144895539,""],["FCM","ExtraTrees especializado",20.598437197475324,0.0,"Ganador especializado"],["FCM","CatBoost especializado",33.06608954182547,60.52717604167688,""]]],"hovertemplate":"%{customdata[0]}\u003cbr\u003e%{customdata[1]}\u003cbr\u003eWAPE: %{customdata[2]:.2f}%\u003cbr\u003eBrecha respecto del mejor: %{customdata[3]:.2f}%\u003cbr\u003e%{customdata[4]}\u003cextra\u003e\u003c\u002fextra\u003e","text":[["75.84%","75.91%","98.37%","74.54% \u2713","79.64%"],["433.73%","355.98%","542.88%","332.74% \u2713","386.11%"],["60.43%","114.93%","78.98%","58.48% \u2713","67.67%"],["22.81%","62.86%","33.99%","19.50% \u2713","23.62%"],["27.14%","72.82%","76.49%","20.60% \u2713","33.07%"]],"texttemplate":"%{text}","x":["Conjunto\u003cbr\u003eExtraTrees global","Persistencia","Ridge\u003cbr\u003eespecializado","ExtraTrees\u003cbr\u003eespecializado","CatBoost\u003cbr\u003eespecializado"],"y":["Transferencias\u003cbr\u003ecorrientes","Transferencias de\u003cbr\u003ecapital","Otros ingresos","IPP","FCM"],"z":{"dtype":"f8","bdata":"aMsQNj7g+z94zweotEX9P29aYQ5v9z9AAAAAAAAAAACs3mXh11MbQKwwDRR4WT5AvAnosCjuG0B+VdDfiJNPQAAAAAAAAAAAOmEZmLwJMEC+b2kVj6kKQOMrvvzqIFhApITQFOqEQUAAAAAAAAAAAMTZq13GZi9AxLru1\u002f\u002fyMEB5zlZ8uH9lQOcswZxkkVJAAAAAAAAAAABgIbhyyhw1QOpylQT7vz9Aec5WfLh\u002fZUB5zlZ8uH9lQAAAAAAAAAAAVB4pgXpDTkA=" ...

# %% [markdown]
# ## Frontera de las 32 combinaciones y mapa congelado
#
# El eje vertical muestra la mejora relativa promedio en los tres ingresos prioritarios:
# más arriba es mejor. El eje horizontal muestra el WAPE macro de `Total disponible`:
# más a la izquierda es mejor. La línea horizontal marca el requisito estricto de 5 % y
# la vertical, el guardrail del total; solo las combinaciones ubicadas en la zona verde
# son elegibles. El color indica cuántos ingresos usan un especialista y la línea verde
# une las combinaciones no dominadas.
#
# Las decisiones centrales se etiquetan directamente: `00000` es el modelo conjunto y
# la combinación congelada se destaca como seleccionada. En cada código, `0` significa
# fuente conjunta y `1`, fuente especializada, siguiendo el orden canónico de los cinco
# ingresos.
#
# La tabla conserva las cinco mejores combinaciones y `00000` como referencia auditable
# del modelo conjunto.

# %%
combination_ranking = workflow.combination_ranking.copy()
combination_ranking["WAPE promedio ingresos (%)"] = (
    100 * combination_ranking["wape_macro_promedio_ingresos"]
).round(2)
combination_ranking["WAPE total (%)"] = (
    100 * combination_ranking["wape_macro_total"]
).round(2)
combination_ranking["Límite total (%)"] = (
    100 * combination_ranking["limite_wape_total"]
).round(2)
combination_ranking["Mejora prioritaria promedio (%)"] = (
    100 * combination_ranking["mejora_relativa_promedio_prioritaria"]
).round(2)
priority_improvement_labels = {
    column: f"Mejora {group} (%)"
    for group, column in SATISFACTORY_IMPROVEMENT_COLUMNS
}
for source_column, display_column in priority_improvement_labels.items():
    combination_ranking[display_column] = (
        100 * combination_ranking[source_column]
    ).round(2)
combination_audit = pd.concat(
    [
        combination_ranking.head(5),
        combination_ranking.loc[combination_ranking["codigo"].eq("00000")],
    ],
    ignore_index=True,
).drop_duplicates("codigo")
display_collapsible(
    "Ver ranking de combinaciones híbridas",
    combination_audit[
        [
            "ranking",
            "seleccionada",
            "codigo",
            "ingresos_especializados",
            "elegible",
            "criterio_mejora_prioritaria_cumplido",
            "guardrail_cumplido",
            "Mejora prioritaria promedio (%)",
            *priority_improvement_labels.values(),
            "WAPE promedio ingresos (%)",
            "WAPE total (%)",
            "Límite total (%)",
        ]
    ]
)

source_map = pd.DataFrame(
    [
        {
            "grupo_ingreso": group,
            "fuente_final": workflow.selected_source_map[group],
        }
        for group in FORECAST_INCOME_GROUPS
    ]
)
display_collapsible("Ver mapa de fuentes seleccionado", source_map)

acceptance_display = workflow.acceptance.copy()
for source_column, display_column in priority_improvement_labels.items():
    acceptance_display[display_column] = (
        100 * acceptance_display[source_column]
    ).round(2)
acceptance_display["Mejora prioritaria promedio (%)"] = (
    100 * acceptance_display["mejora_relativa_promedio_prioritaria"]
).round(2)
acceptance_display["Umbral estricto (%)"] = (
    100 * acceptance_display["umbral_mejora_relativa_prioritaria"]
).round(2)
display_collapsible(
    "Ver criterio de mejora satisfactoria",
    acceptance_display[
        [
            "codigo_seleccionado",
            *priority_improvement_labels.values(),
            "Mejora prioritaria promedio (%)",
            "Umbral estricto (%)",
            "criterio_mejora_prioritaria_cumplido",
            "guardrail_cumplido",
            "combinaciones_hibridas_elegibles",
            "mejora_satisfactoria",
            "motivo_seleccion",
        ]
    ],
)

combination_figure = plot_hybrid_combination_frontier(
    workflow.combination_ranking
)
display(
    HTML(
        combination_figure.to_html(
            full_html=False,
            include_plotlyjs="cdn",
            config={"responsive": True, "displaylogo": False},
        )
    )
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver ranking de combinaciones híbridas</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>ranking</th>
#       <th>seleccionada</th>
#       <th>codigo</th>
#       <th>ingresos_especializados</th>
#       <th>elegible</th>
#       <th>criterio_mejora_prioritaria_cumplido</th>
#       <th>guardrail_cumplido</th>
#       <th>Mejora prioritaria promedio (%)</th>
#       <th>Mejora Transferencias corrientes (%)</th>
#       <th>Mejora Transferencias de capital (%)</th>
#       <th>Mejora Otros ingresos (%)</th>
#       <th>WAPE promedio ingresos (%)</th>
#       <th>WAPE total (%)</th>
#       <th>Límite total (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1</td>
#       <td>True</td>
#       <td>11111</td>
#       <td>5</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>9.41</td>
#       <td>1.71</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>101.17</td>
#       <td>18.97</td>
#       <td>23.48</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2</td>
#       <td>False</td>
#       <td>11110</td>
#       <td>4</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>9.41</td>
#       <td>1.71</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>102.48</td>
#       <td>19.09</td>
#       <td>23.48</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3</td>
#       <td>False</td>
#       <td>11101</td>
#       <td>4</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>9.41</td>
#       <td>1.71</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>101.84</td>
#       <td>22.02</td>
#       <td>23.48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4</td>
#       <td>False</td>
#       <td>11100</td>
#       <td>3</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>9.41</td>
#       <td>1.71</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>103.14</td>
#       <td>22.09</td>
#       <td>23.48</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#       <td>False</td>
#       <td>01111</td>
#       <td>4</td>
#       <td>True</td>
#       <td>True</td>
#       <td>True</td>
#       <td>8.84</td>
#       <td>0.00</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>101.43</td>
#       <td>19.04</td>
#       <td>23.48</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>32</td>
#       <td>False</td>
#       <td>00000</td>
#       <td>0</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>0.00</td>
#       <td>123.99</td>
#       <td>22.48</td>
#       <td>23.48</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver mapa de fuentes seleccionado</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grupo_ingreso</th>
#       <th>fuente_final</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Transferencias corrientes</td>
#       <td>especializado</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Transferencias de capital</td>
#       <td>especializado</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Otros ingresos</td>
#       <td>especializado</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>IPP</td>
#       <td>especializado</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>FCM</td>
#       <td>especializado</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver criterio de mejora satisfactoria</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>codigo_seleccionado</th>
#       <th>Mejora Transferencias corrientes (%)</th>
#       <th>Mejora Transferencias de capital (%)</th>
#       <th>Mejora Otros ingresos (%)</th>
#       <th>Mejora prioritaria promedio (%)</th>
#       <th>Umbral estricto (%)</th>
#       <th>criterio_mejora_prioritaria_cumplido</th>
#       <th>guardrail_cumplido</th>
#       <th>combinaciones_hibridas_elegibles</th>
#       <th>mejora_satisfactoria</th>
#       <th>motivo_seleccion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11111</td>
#       <td>1.71</td>
#       <td>23.28</td>
#       <td>3.23</td>
#       <td>9.41</td>
#       <td>5.0</td>
#       <td>True</td>
#       <td>True</td>
#       <td>16</td>
#       <td>True</td>
#       <td>híbrida: mayor mejora relativa promedio en ing...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <div style="height:660px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="5b6dd373-9930-40d3-8b6a-65db535d56f5" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5b6dd373-9930-40d3-8b6a-65db535d56f5")) {                    Plotly.newPlot(                        "5b6dd373-9930-40d3-8b6a-65db535d56f5",                        [{"customdata":[["11110",2,4,true,true,true],["11101",3,4,true,true,true],["11100",4,3,true,true,true],["01111",5,4,true,true,true],["01110",6,3,true,true,true],["01101",7,3,true,true,true],["01100",8,2,true,true,true],["11011",9,4,true,true,true],["11010",10,3,true,true,true],["11001",11,3,true,true,true],["11000",12,2,true,true,true],["01011",13,3,true,true,true],["01010",14,2,true,true,true],["01001",15,2,true,true,true],["01000",16,1,true,true,true]],"hovertemplate":"\u003cb\u003eCombinaci\u00f3n %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003eRanking: %{customdata[1]}\u003cbr\u003eIngresos especializados: %{customdata[2]} de 5\u003cbr\u003eWAPE total: %{x:.2f}%\u003cbr\u003eMejora prioritaria promedio: %{y:.2f}%\u003cbr\u003eCumple guardrail: %{customdata[3]}\u003cbr\u003eSupera 5%: %{customdata[4]}\u003cbr\u003eElegible: %{customdata[5]}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"cmax":5,"cmin":0,"color":{"dtype":"i1","bdata":"BAQDBAMDAgQDAwIDAgIB"},"colorbar":{"len":0.28,"orientation":"h","outlinewidth":0,"thickness":10,"tickmode":"array","ticktext":["0","1","2","3","4","5"],"tickvals":[0,1,2,3,4,5],"title":{"side":"top","text":"Ingresos especializados"},"x":1.0,"xanchor":"right","y":1.08,"yanchor":"bottom"},"colorscale":[[0.0,"#DCEAF6"],[0.5,"#5B9CC9"],[1.0,"#145A8D"]],"line":{"color":"#FFFFFF","width":0.9},"opacity":0.78,"size":10},"mode":"markers","name":"Combinaciones elegibles","showlegend":false,"x":{"dtype":"f8","bdata":"ZUlJsysXM0AxVydfRAQ2QKD\u002ffSbLFjZAhhKN89AJM0ApOnFmxzkzQP8tD4NbDDZAD6POq1QiNkAw2HrjP\u002fAyQLDcbQlzDTNAMVlfrXAaNkBwYFO3uy02QChhXsdj\u002fjJACAoL0\u002fAuM0B5qEvWOCk2QIPara2dPzZA"},"y":{"dtype":"f8","bdata":"6ztnAl3QIkDrO2cCXdAiQOs7ZwJd0CJAH6IpkhysIUAfoimSHKwhQB+iKZIcrCFAH6IpkhysIUCHc8iB6akgQIdzyIHpqSBAh3PIgempIECHc8iB6akgQHezFSNSCx9Ad7MVI1ILH0B3sxUjUgsfQHezFSNSCx9A"},"type":"scatter"},{"customdata":[["10111",17,4,true,false,false],["10110",18,3,true,false,false],["10101",19,3,true,false,false],["10100",20,2,true,false,false],["00111",21,3,true,false,false],["00110",22,2,true,false,false],["00101",23,2,true,false,false],["00100",24,1,true,false,false],["10011",25,3,true,false,false],["10010",26,2,true,false,false],["10001",27,2,true,false,false],["10000",28,1,true,false,false],["00011",29,2,true,false,false],["00010",30,1,true,false,false],["00001",31,1,true,false,false]],"hovertemplate":"\u003cb\u003eCombinaci\u00f3n %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003eRanking: %{customdata[1]}\u003cbr\u003eIngresos especializados: %{customdata[2]} de 5\u003cbr\u003eWAPE total: %{x:.2f}%\u003cbr\u003eMejora prioritaria promedio: %{y:.2f}%\u003cbr\u003eCumple guardrail: %{customdata[3]}\u003cbr\u003eSupera 5%: %{customdata[4]}\u003cbr\u003eElegible: %{customdata[5]}\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"cmax":5,"cmin":0,"color":{"dtype":"i1","bdata":"BAMDAgMCAgEDAgIBAgEB"},"colorbar":{"len":0.28,"orientation":"h","outlinewidth":0,"thickness":10,"tickmode":"array","ticktext":["0","1","2","3","4","5"],"tickvals":[0,1,2,3,4,5],"title":{"side":"top","text":"Ingresos especializados"},"x":1.0,"xanchor":"right","y":1.08,"yanchor":"bottom"},"colorscale":[[0.0,"#DCEAF6"],[0.5,"#5B9CC9"],[1.0,"#145A8D"]],"line":{"width":1.5},"showscale":false,"size":11,"symbol":"x"},"mode":"markers","name":"Combinaciones no elegibles","showlegend":false,"x":{"dtype":"f8","bdata":"gFTsan8ZM0CEqxFxWzozQKWsoSZCMjZ ...

# %% [markdown]
# ## Cuánto mejora frente a `cluster1.ipynb`
#
# La comparación usa como línea base el ganador conjunto de `cluster1.ipynb`. La
# diferencia en puntos porcentuales es `WAPE híbrido - WAPE conjunto`: un valor negativo
# indica menor error. La mejora relativa usa al conjunto como denominador. La selección
# se decide con tres cortes históricos cuyos objetivos abarcan enero de 2024 a junio de
# 2025. Después, julio-diciembre de 2025 se usa como entrada final y enero-junio de 2026
# queda reservado como test congelado. El test 2026 solo mide cuánto se sostuvo fuera de
# muestra y no puede cambiar la arquitectura seleccionada.

# %%
executive_comparison = comparison_summary.loc[
    comparison_summary["grupo_ingreso"].isin(
        ["Total disponible", AVERAGE_INCOME_GROUP_LABEL]
    )
].copy()
executive_comparison["WAPE conjunto (%)"] = (
    100 * executive_comparison["wape_conjunto"]
).round(2)
executive_comparison["WAPE híbrido (%)"] = (
    100 * executive_comparison["wape_hibrido"]
).round(2)
executive_comparison["Mejora relativa (%)"] = (
    100 * executive_comparison["mejora_relativa"]
).round(2)
display_collapsible(
    "Ver comparación ejecutiva conjunto versus híbrido",
    executive_comparison[
        [
            "periodo",
            "grupo_ingreso",
            "modelo_conjunto",
            "WAPE conjunto (%)",
            "WAPE híbrido (%)",
            "diferencia_wape_pp",
            "Mejora relativa (%)",
        ]
    ]
)

improvement_figure = plot_joint_hybrid_improvement_matrix(
    comparison_summary,
    joint_model_name=workflow.joint_selected_model_name,
)
display(
    HTML(
        improvement_figure.to_html(
            full_html=False,
            include_plotlyjs="cdn",
            config={"responsive": True, "displaylogo": False},
        )
    )
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver comparación ejecutiva conjunto versus híbrido</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>periodo</th>
#       <th>grupo_ingreso</th>
#       <th>modelo_conjunto</th>
#       <th>WAPE conjunto (%)</th>
#       <th>WAPE híbrido (%)</th>
#       <th>diferencia_wape_pp</th>
#       <th>Mejora relativa (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Validación histórica · objetivos ene-2024 a ju...</td>
#       <td>Total disponible</td>
#       <td>ExtraTrees global</td>
#       <td>22.48</td>
#       <td>18.97</td>
#       <td>-3.510782</td>
#       <td>15.62</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Validación histórica · objetivos ene-2024 a ju...</td>
#       <td>Promedio de los cinco ingresos</td>
#       <td>ExtraTrees global</td>
#       <td>123.99</td>
#       <td>101.17</td>
#       <td>-22.815875</td>
#       <td>18.40</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Test congelado · objetivos ene-jun 2026</td>
#       <td>Total disponible</td>
#       <td>ExtraTrees global</td>
#       <td>19.69</td>
#       <td>16.48</td>
#       <td>-3.210851</td>
#       <td>16.30</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Test congelado · objetivos ene-jun 2026</td>
#       <td>Promedio de los cinco ingresos</td>
#       <td>ExtraTrees global</td>
#       <td>222.81</td>
#       <td>101.23</td>
#       <td>-121.582411</td>
#       <td>54.57</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <div style="height:690px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="8daf7c42-eb85-4a95-8a7f-fb0facda1633" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("8daf7c42-eb85-4a95-8a7f-fb0facda1633")) {                    Plotly.newPlot(                        "8daf7c42-eb85-4a95-8a7f-fb0facda1633",                        [{"colorbar":{"title":{"text":"Mejora\u003cbr\u003erelativa (%)"}},"colorscale":[[0.0,"#D55E00"],[0.5,"#F7F7F7"],[1.0,"#009E73"]],"customdata":[[["Total disponible","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",22.483263274774295,18.97248099963206,-3.510782275142235,"+15.6%"],["Total disponible","Test congelado \u00b7 objetivos ene-jun 2026",19.694007696008214,16.483157068707648,-3.210850627300568,"+16.3%"]],[["Transferencias corrientes","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",75.84268275050589,74.54394326263873,-1.298739487867151,"+1.7%"],["Transferencias corrientes","Test congelado \u00b7 objetivos ene-jun 2026",53.73751420615267,60.06299243599054,6.3254782298378665,"-11.8%"]],[["Transferencias de capital","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",433.72918708734005,332.74329809727965,-100.98588899006037,"+23.3%"],["Transferencias de capital","Test congelado \u00b7 objetivos ene-jun 2026",967.4836577231188,362.35140477961056,-605.1322529435083,"+62.5%"]],[["Otros ingresos","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",60.43410380003191,58.48492271624855,-1.949181083783369,"+3.2%"],["Otros ingresos","Test congelado \u00b7 objetivos ene-jun 2026",53.34604472590804,51.94864782252955,-1.3973969033784894,"+2.6%"]],[["IPP","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",22.808393686048554,19.502818740989845,-3.3055749450587064,"+14.5%"],["IPP","Test congelado \u00b7 objetivos ene-jun 2026",19.978157041322234,16.444631442643864,-3.533525598678369,"+17.7%"]],[["FCM","Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025",27.138425348591323,20.598437197475324,-6.539988151115997,"+24.1%"],["FCM","Test congelado \u00b7 objetivos ene-jun 2026",19.516559378008164,15.342202699749125,-4.1743566782590396,"+21.4%"]]],"hovertemplate":"%{customdata[0]}\u003cbr\u003e%{customdata[1]}\u003cbr\u003eConjunto ExtraTrees global: %{customdata[2]:.2f}%\u003cbr\u003eH\u00edbrido: %{customdata[3]:.2f}%\u003cbr\u003eDiferencia: %{customdata[4]:+.2f} pp\u003cbr\u003eMejora relativa: %{customdata[5]}\u003cextra\u003e\u003c\u002fextra\u003e","text":[["22.48 \u2192 18.97%\u003cbr\u003e-3.51 pp \u00b7 +15.6%","19.69 \u2192 16.48%\u003cbr\u003e-3.21 pp \u00b7 +16.3%"],["75.84 \u2192 74.54%\u003cbr\u003e-1.30 pp \u00b7 +1.7%","53.74 \u2192 60.06%\u003cbr\u003e+6.33 pp \u00b7 -11.8%"],["433.73 \u2192 332.74%\u003cbr\u003e-100.99 pp \u00b7 +23.3%","967.48 \u2192 362.35%\u003cbr\u003e-605.13 pp \u00b7 +62.5%"],["60.43 \u2192 58.48%\u003cbr\u003e-1.95 pp \u00b7 +3.2%","53.35 \u2192 51.95%\u003cbr\u003e-1.40 pp \u00b7 +2.6%"],["22.81 \u2192 19.50%\u003cbr\u003e-3.31 pp \u00b7 +14.5%","19.98 \u2192 16.44%\u003cbr\u003e-3.53 pp \u00b7 +17.7%"],["27.14 \u2192 20.60%\u003cbr\u003e-6.54 pp \u00b7 +24.1%","19.52 \u2192 15.34%\u003cbr\u003e-4.17 pp \u00b7 +21.4%"]],"texttemplate":"%{text}","x":["Validaci\u00f3n hist\u00f3rica \u00b7 objetivos ene-2024 a jun-2025","Test congelado \u00b7 objetivos ene-jun 2026"],"xgap":3,"y":["Total disponible","Transferencias\u003cbr\u003ecorrientes","Transferencias de\u003cbr\u003ecapital","Otros ingresos","IPP","FCM"],"ygap":3,"z":{"dtype":"f8","bdata":"KkUxW+06L0AsQErZvk0wQBBrxoUKZvs\u002fZpWIJ8mKJ8CZRlCafUg3QLl48vAERk9AqmRxB2rNCUC9vpC5ufQEQJ8spFFQ\u002fCxAT7SCnNuvMUCCihquPxk4QB4QqQCIYzVA","shape":"6, 2"},"zm ...

# %% [markdown]
# ## Lectura del test congelado de 2026
#
# Solo después de fijar el mapa anterior se comparan las cuatro alternativas sobre
# enero–junio de 2026. La máscara de meses observados es la misma del benchmark, de modo
# que la comparación conjunta, separada e híbrida usa idéntica cobertura efectiva.

# %%
test_comparison = comparison_summary.loc[
    comparison_summary["periodo"].eq(TEST_PERIOD_LABEL)
    & ~comparison_summary["grupo_ingreso"].eq(AVERAGE_INCOME_GROUP_LABEL)
].copy()
test_comparison["WAPE conjunto (%)"] = (
    100 * test_comparison["wape_conjunto"]
).round(2)
test_comparison["WAPE híbrido (%)"] = (
    100 * test_comparison["wape_hibrido"]
).round(2)
test_comparison["Mejora relativa (%)"] = (
    100 * test_comparison["mejora_relativa"]
).round(2)
display_collapsible(
    "Ver comparación del test congelado de 2026",
    test_comparison[
        [
            "grupo_ingreso",
            "WAPE conjunto (%)",
            "WAPE híbrido (%)",
            "diferencia_wape_pp",
            "Mejora relativa (%)",
            "mejora",
        ]
    ]
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver comparación del test congelado de 2026</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>grupo_ingreso</th>
#       <th>WAPE conjunto (%)</th>
#       <th>WAPE híbrido (%)</th>
#       <th>diferencia_wape_pp</th>
#       <th>Mejora relativa (%)</th>
#       <th>mejora</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>7</th>
#       <td>Total disponible</td>
#       <td>19.69</td>
#       <td>16.48</td>
#       <td>-3.210851</td>
#       <td>16.30</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Transferencias corrientes</td>
#       <td>53.74</td>
#       <td>60.06</td>
#       <td>6.325478</td>
#       <td>-11.77</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Transferencias de capital</td>
#       <td>967.48</td>
#       <td>362.35</td>
#       <td>-605.132253</td>
#       <td>62.55</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Otros ingresos</td>
#       <td>53.35</td>
#       <td>51.95</td>
#       <td>-1.397397</td>
#       <td>2.62</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>IPP</td>
#       <td>19.98</td>
#       <td>16.44</td>
#       <td>-3.533526</td>
#       <td>17.69</td>
#       <td>True</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>FCM</td>
#       <td>19.52</td>
#       <td>15.34</td>
#       <td>-4.174357</td>
#       <td>21.39</td>
#       <td>True</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>

# %% [markdown]
# ## Cobertura efectiva del test
#
# La cobertura se calcula una vez por comuna sobre `Total disponible` para la solución
# híbrida. Una comuna con menos de seis meses evaluados tiene meses finales no
# reportados que no participan en WAPE, MAE ni sesgo.

# %%
coverage_details = workflow.test_details.loc[
    workflow.test_details["modelo"].eq(HYBRID_ARCHITECTURE)
    & workflow.test_details["grupo_ingreso"].eq("Total disponible")
].copy()
coverage = (
    coverage_details.groupby("Nombre Municipio", sort=True, observed=True)
    .agg(
        meses_evaluados=("observado_mm_clp", lambda values: values.notna().sum()),
        meses_no_reportados=(
            "fecha",
            lambda dates: [
                date.strftime("%Y-%m")
                for date in dates[
                    coverage_details.loc[dates.index, "observado_mm_clp"].isna()
                ]
            ],
        ),
    )
    .reset_index()
)
coverage["cobertura_completa"] = coverage["meses_evaluados"].eq(6)
display_collapsible(
    "Ver comunas con cobertura incompleta",
    coverage.loc[~coverage["cobertura_completa"]],
)
display_collapsible(
    "Ver cobertura total evaluada",
    (
        f'Meses comuna evaluados: {int(coverage["meses_evaluados"].sum())} '
        f"de {6 * len(coverage)}"
    ),
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver comunas con cobertura incompleta</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Nombre Municipio</th>
#       <th>meses_evaluados</th>
#       <th>meses_no_reportados</th>
#       <th>cobertura_completa</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Alhué</td>
#       <td>3</td>
#       <td>[2026-04, 2026-05, 2026-06]</td>
#       <td>False</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver cobertura total evaluada</summary><div class="collapsible-output__content"><pre class="collapsible-output__text">Meses comuna evaluados: 27 de 30</pre></div></details>

# %% [markdown]
# ## Dónde mejora dentro del clúster y detalle configurable
#
# Cambie `PREFERRED_MUNICIPALITY` en la celda inicial para inspeccionar otra comuna del
# clúster. El panel izquierdo ordena las comunas por la reducción relativa del WAPE total
# en el test de enero a junio de 2026. Una barra verde positiva significa que el híbrido
# reduce el error frente al ExtraTrees conjunto; una barra naranja negativa significa
# que lo aumenta. La etiqueta `n/6` informa cuántos meses tenían datos observados y
# entraron realmente en la métrica, por lo que los resultados con 4/6 o 5/6 deben
# interpretarse con más cautela.
#
# El círculo identifica la comuna elegida y el panel derecho permite entender su barra:
# compara mes a mes lo observado, Persistencia, el modelo conjunto de `cluster1.ipynb` y
# el híbrido. El WAPE mostrado en la leyenda se calcula solo sobre los meses reportados.
# Por eso el híbrido puede mejorar el resultado agregado del clúster y, al mismo tiempo,
# ser peor para una comuna particular. `Separado completo` no se duplica cuando coincide
# con el híbrido.

# %%
municipality_view = build_separated_municipality_forecast_view(
    workflow,
    PREFERRED_MUNICIPALITY,
)

municipality_metrics = municipality_view.metrics.loc[
    municipality_view.metrics["grupo_ingreso"].eq("Total disponible")
    & municipality_view.metrics["modelo"].isin(
        ["Persistencia", JOINT_ARCHITECTURE, HYBRID_ARCHITECTURE]
    )
].copy()
municipality_metrics["WAPE total (%)"] = (
    100 * municipality_metrics["wape"]
).round(2)
display_collapsible(
    f"Ver métricas de {municipality_view.municipality}",
    municipality_metrics[
        [
            "modelo",
            "WAPE total (%)",
            "mae_mm_clp",
            "sesgo_mm_clp",
            "meses_evaluados",
        ]
    ]
)

municipality_figure = plot_cluster_municipality_improvement(
    workflow.test_unit_metrics,
    municipality_view.actual,
    municipality_view.forecasts,
    municipality_view.metrics,
    municipality=municipality_view.municipality,
    joint_model_name=workflow.joint_selected_model_name,
)
display(
    HTML(
        municipality_figure.to_html(
            full_html=False,
            include_plotlyjs="cdn",
            config={"responsive": True, "displaylogo": False},
        )
    )
)
# Out:
# <details class="collapsible-output" ontoggle="if(this.open&amp;&amp;window.Plotly){for(const plot of this.querySelectorAll('.plotly-graph-div')){window.Plotly.Plots.resize(plot)}}"><summary>Ver métricas de Providencia</summary><div class="collapsible-output__content"><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>modelo</th>
#       <th>WAPE total (%)</th>
#       <th>mae_mm_clp</th>
#       <th>sesgo_mm_clp</th>
#       <th>meses_evaluados</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>3</th>
#       <td>Conjunto seleccionado</td>
#       <td>18.68</td>
#       <td>2097.772546</td>
#       <td>-1037.547362</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Híbrido seleccionado</td>
#       <td>7.35</td>
#       <td>825.898172</td>
#       <td>-466.132543</td>
#       <td>6.0</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Persistencia</td>
#       <td>43.65</td>
#       <td>4902.671758</td>
#       <td>-1027.092460</td>
#       <td>6.0</td>
#     </tr>
#   </tbody>
# </table>
# </div></div></details>
# <div style="height:780px; width:100%;">                        <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.7.0.min.js" integrity="sha256-jvTGqxNp8AGWEcvNLVuKr+8j5dGe9Yw51LQkmDH+IYA=" crossorigin="anonymous"></script>                <div id="ad9a311c-6449-4fe4-ac0d-8a8cdadfdc9e" class="plotly-graph-div" style="height:100%; width:100%;"></div>            <script>                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("ad9a311c-6449-4fe4-ac0d-8a8cdadfdc9e")) {                    Plotly.newPlot(                        "ad9a311c-6449-4fe4-ac0d-8a8cdadfdc9e",                        [{"customdata":{"dtype":"f8","bdata":"VB+p1hRdMUAmoaaFZAFDQAAAAAAAAAhA\u002fc5x1pAXJkCylXYALnAjQAAAAAAAABhAynOHqV5rNkAzCCIkWK8uQAAAAAAAABhANS32\u002fwr3PEC9CXHBKfsnQAAAAAAAABhAf\u002fu7hQ2tMkAORMqoP2kdQAAAAAAAABhA","shape":"5, 3"},"hovertemplate":"%{y}\u003cbr\u003eWAPE conjunto: %{customdata[0]:.2f}%\u003cbr\u003eWAPE h\u00edbrido: %{customdata[1]:.2f}%\u003cbr\u003eMejora relativa: %{x:+.2f}%\u003cbr\u003eMeses evaluados: %{customdata[2]:.0f}\u002f6\u003cextra\u003e\u003c\u002fextra\u003e","marker":{"color":["#D55E00","#009E73","#009E73","#009E73","#009E73"]},"name":"Mejora municipal","orientation":"h","showlegend":false,"text":["-118.9% \u00b7 3\u002f6","+12.0% \u00b7 6\u002f6","+31.6% \u00b7 6\u002f6","+58.6% \u00b7 6\u002f6","+60.6% \u00b7 6\u002f6"],"textposition":"outside","x":{"dtype":"f8","bdata":"7h\u002f6rlK6XcBySp5ygAYoQMcTxbHukD9ALrs\u002fnTlNTUADlz3Xm1BOQA=="},"y":["Alhu\u00e9","Vitacura","Lo Barnechea","Huechuraba","Providencia"],"type":"bar","xaxis":"x","yaxis":"y"},{"hoverinfo":"skip","marker":{"color":"#222222","line":{"width":2},"size":18,"symbol":"circle-open"},"mode":"markers","name":"Providencia","showlegend":false,"x":{"dtype":"f8","bdata":"A5c915tQTkA="},"y":["Providencia"],"type":"scatter","xaxis":"x","yaxis":"y"},{"connectgaps":false,"hovertemplate":"%{x|%b %Y}\u003cbr\u003eObservado: %{y:,.2f} MM CLP\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"#222222","width":3},"marker":{"size":8},"mode":"lines+markers","name":"Observado","x":["2026-01-01T00:00:00.000000","2026-02-01T00:00:00.000000","2026-03-01T00:00:00.000000","2026-04-01T00:00:00.000000","2026-05-01T00:00:00.000000","2026-06-01T00:00:00.000000"],"y":{"dtype":"f8","bdata":"OZojK19Z00AH0sWmLYW8QE9ZTdeDi8dAO1lqvSeyt0APR1fpNybQQI\u002fgRsoG9rVA"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"%{x|%b %Y}\u003cbr\u003ePersistencia: %{y:,.2f} MM CLP\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"#E69F00","dash":"dash","width":2.5},"marker":{"size":7},"mode":"lines+markers","name":"Persistencia \u00b7 43.65%","x":["2026-01-01T00:00:00.000000","2026-02-01T00:00:00.000000","2026-03-01T00:00:00.000000","2026-04-01T00:00:00.000000","2026-05-01T00:00:00.000000","2026-06-01T00:00:00.000000"],"y":{"dtype":"f8","bdata":"yM7b2K7uw0DIztvYru7DQMjO29iu7sNAyM7b2K7uw0DIztvYru7DQMjO29iu7sNA"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"%{x|%b %Y}\u003cbr\u003eConjunto: %{y:,.2f} MM CLP\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"#0072B2","dash":"dot","width":2.5},"marker":{"size":7},"mode":"lines+markers","name":"Conjunto \u00b7 18.68%","x":["2026-01-01T00:00:00.000000","2026-02-01T00:00:00.000000","2026-03-01T00:00:00.000000","2026-04-01T00:00:00.000000","2026-05-01T00:00:00.000000","2026-06-01T00:00:00.000000"],"y":{"dtype":"f8","bdata":"5KckYzLoz0B4VF+KSJC7QFSZMui5JcNAIzmP83LSvkBZsOFqPZjJQFsbLYVoQrtA"},"type":"scatter","xaxis":"x2","yaxis":"y2"},{"hovertemplate":"%{x|%b %Y}\u003cbr\u003eH\u00edbrido seleccionado: %{y:,.2f} MM CLP\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"#009E73","dash":"solid","width":2.5},"marker":{"size":7},"mode":"lines+markers","name":"H\u00edbrido seleccionado \u00b7 7.35%","x":["2026-01-01T00:00:00.000000","2026-02-01T00:00:00.000000","2026-03-01T00:00:00.000000","2026-04-01T00:00:00.000000","2026-05-01T00:00:00.000000","2026-06-01T00:00:00.000000"],"y":{"dtype":"f ...

# %% [markdown]
# ## Conclusión metodológica del experimento
#
# La combinación híbrida se adopta solamente cuando la mejora relativa promedio de
# `Transferencias corrientes`, `Transferencias de capital` y `Otros ingresos` supera
# estrictamente el 5 % en validación histórica y, al mismo tiempo, se respeta el
# guardrail de `Total disponible`. Si ninguna combinación cumple ambas condiciones, el
# flujo vuelve al modelo conjunto `00000`.
#
# El test congelado de enero a junio de 2026 se utiliza solo para comprobar cuánto se
# sostuvo el desempeño fuera de muestra. Una mejora posterior aporta evidencia
# diagnóstica, pero no puede modificar la combinación seleccionada con objetivos de
# enero de 2024 a junio de 2025.
