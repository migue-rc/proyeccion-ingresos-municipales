# %% [markdown]
# La idea es poder ver como esta estructurados los datos.
#
# [contraloria.cl](https://www.contraloria.cl/portalweb/web/cgr/base-de-datos-municipales)

# %%
import pandas as pd

patrimonial_2025_df = pd.read_excel('data/BD Patrimonial 2025_09-06-2026.xlsx')
patrimonial_2025_df
# Out:
#        Ejercicio Región  Cod Municipio Nombre Municipio  Cod Serv Incorporado  \
# 0           2025      I           7501          Iquique                     1
# 1           2025      I           7501          Iquique                     1
# 2           2025      I           7501          Iquique                     1
# 3           2025      I           7501          Iquique                     1
# 4           2025      I           7501          Iquique                     1
# ...          ...    ...            ...              ...                   ...
# 73491       2025    XVI           9021      San Nicolás                     3
# 73492       2025    XVI           9021      San Nicolás                     3
# 73493       2025    XVI           9021      San Nicolás                     3
# 73494       2025    XVI           9021      San Nicolás                     3
# 73495       2025    XVI           9021      San Nicolás                     3
#
# ...

# %%
presupuesto_2025_df = pd.read_excel('data/BD Presupuestaria 2025_09-06-2026.xlsx')
presupuesto_2025_df
# Out:
#         Ejercicio Moneda Región  Cod Municipio Nombre Municipio  \
# 0            2025    CLP      I           7502    Alto Hospicio
# 1            2025    CLP      I           7502    Alto Hospicio
# 2            2025    CLP      I           7502    Alto Hospicio
# 3            2025    CLP      I           7502    Alto Hospicio
# 4            2025    CLP      I           7502    Alto Hospicio
# ...           ...    ...    ...            ...              ...
# 162556       2025    CLP    XVI           9019           Ñiquén
# 162557       2025    CLP    XVI           9019           Ñiquén
# 162558       2025    CLP    XVI           9019           Ñiquén
# 162559       2025    CLP    XVI           9019           Ñiquén
# 162560       2025    CLP    XVI           9019           Ñiquén
#
#         Cod Serv Incorporado Nombre Serv Incorporado  Cod Subárea  \
# 0                          1       Gestión Municipal            0
# ...

# %%
presupuesto_2025_df.describe()
# Out:
#        Ejercicio  Cod Municipio  Cod Serv Incorporado    Cod Subárea  \
# count   162561.0  162561.000000         162561.000000  162561.000000
# mean      2025.0    8277.152189              1.577715       1.099009
# std          0.0     377.849164              0.847865       1.512964
# min       2025.0    7501.000000              1.000000       0.000000
# 25%       2025.0    8008.000000              1.000000       0.000000
# 50%       2025.0    8223.000000              1.000000       1.000000
# 75%       2025.0    8602.000000              2.000000       1.000000
# max       2025.0    9021.000000              4.000000       6.000000
#
#        Cod Tipo Cuenta  Cod Subtítulo       Cod Ítem  Cod Asignación  \
# count    162561.000000  162561.000000  162561.000000   162561.000000
# mean          1.850456      20.353972       5.991419     6059.738597
# std           0.356625       6.259115      14.006025    14038.683141
# ...

# %% [markdown]
# Columnas usables:
# - `Cod Municipio`
# - `Cod Serv Incorporado`
# - `Cod Tipo Cuenta`
